# %%
import numpy as np
import tensorflow as tf
from keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM
from keras.preprocessing import sequence

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=30000)

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  12118,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
X_train = sequence.pad_sequences(X_train, maxlen=100)
X_test = sequence.pad_sequences(X_test, maxlen=100)

# %%
len(X_train[0])
# Out:
# 100

# %%
model = Sequential()

# %%
model.add(Embedding(input_dim=30000, output_dim=128, ))
model.add(LSTM(units=128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=300, epochs=10, validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 84/84 [==============================] - 64s 761ms/step - loss: 0.4954 - accuracy: 0.7468 - val_loss: 0.3556 - val_accuracy: 0.8396
# Epoch 2/10
# 84/84 [==============================] - 62s 744ms/step - loss: 0.2454 - accuracy: 0.9025 - val_loss: 0.3482 - val_accuracy: 0.8479
# Epoch 3/10
# 84/84 [==============================] - 63s 746ms/step - loss: 0.1580 - accuracy: 0.9456 - val_loss: 0.4019 - val_accuracy: 0.8354
# Epoch 4/10
# 84/84 [==============================] - 62s 735ms/step - loss: 0.1011 - accuracy: 0.9671 - val_loss: 0.4924 - val_accuracy: 0.8299
# Epoch 5/10
# 84/84 [==============================] - 62s 734ms/step - loss: 0.0689 - accuracy: 0.9775 - val_loss: 0.5884 - val_accuracy: 0.8231
# Epoch 6/10
# 84/84 [==============================] - 62s 736ms/step - loss: 0.0612 - accuracy: 0.9796 - val_loss: 0.5801 - val_accuracy: 0.8226
# Epoch 7/10
# 84/84 [==============================] - 62s 732ms/step - loss: 0.0548 - accuracy: 0.9824 - val_loss: 0.7676 - val_accuracy: 0.8112
# Epoch 8/10
# 84/84 [==============================] - 62s 734ms/step - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.9736 - val_accuracy: 0.8060
# Epoch 9/10
# 84/84 [==============================] - 61s 725ms/step - loss: 0.0215 - accuracy: 0.9933 - val_loss: 0.8692 - val_accuracy: 0.8146
# Epoch 10/10
# 84/84 [==============================] - 61s 725ms/step - loss: 0.0203 - accuracy: 0.9940 - val_loss: 0.9811 - val_accuracy: 0.8134
