# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Dropout, Dense, Conv2D, MaxPooling2D, Flatten, AveragePooling2D
from keras.utils import np_utils

# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
X_train = X_train.reshape(X_train.shape[0],28,28,1)
X_test = X_test.reshape(X_test.shape[0],28,28,1)

# %%
X_train = X_train/255
X_test = X_test/255

# %%
y_train = np_utils.to_categorical(y_train,10)
y_test = np_utils.to_categorical(y_test,10)

# %%
model = Sequential()

# %%
model.add(Conv2D(filters=6, kernel_size=(5,5), strides=(1,1), padding='same', activation='tanh', input_shape=(28,28,1)))
model.add(AveragePooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters=16, kernel_size=(5,5), strides=(1,1), activation='tanh'))
model.add(AveragePooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters=120, kernel_size=(2,2), strides=(1,1), activation='tanh'))

# %%
model.add(Flatten())

# %%
model.add(Dense(units=84, activation='tanh'))

model.add(Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 120)         7800
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 84)                161364
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                850
# =================================================================
# Total params: 172,586
# Trainable params: 172,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
filepath="/content/drive/My Drive/Data Science/LeNet5_MNIST/weights.{epoch:02d}-{val_accuracy:.2f}.hdf5"

checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, mode='max')

callbacks_list = [checkpoint]

# %%
history = model.fit(x=X_train, y=y_train, batch_size=200, epochs=50, validation_data=(X_test, y_test), callbacks=callbacks_list)
history
# Out:
# Epoch 1/50
# 300/300 [==============================] - ETA: 0s - loss: 0.3525 - accuracy: 0.8995
# Epoch 00001: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.01-0.94.hdf5
# 300/300 [==============================] - 34s 113ms/step - loss: 0.3525 - accuracy: 0.8995 - val_loss: 0.1891 - val_accuracy: 0.9439
# Epoch 2/50
# 300/300 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9511
# Epoch 00002: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.02-0.96.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.1674 - accuracy: 0.9511 - val_loss: 0.1363 - val_accuracy: 0.9617
# Epoch 3/50
# 300/300 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9638
# Epoch 00003: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.03-0.97.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.1228 - accuracy: 0.9638 - val_loss: 0.1092 - val_accuracy: 0.9664
# Epoch 4/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9725
# Epoch 00004: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.04-0.98.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0931 - accuracy: 0.9725 - val_loss: 0.0783 - val_accuracy: 0.9762
# Epoch 5/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9782
# Epoch 00005: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.05-0.98.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0731 - accuracy: 0.9782 - val_loss: 0.0658 - val_accuracy: 0.9804
# Epoch 6/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9825
# Epoch 00006: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.06-0.98.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0588 - accuracy: 0.9825 - val_loss: 0.0624 - val_accuracy: 0.9803
# Epoch 7/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9860
# Epoch 00007: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.07-0.98.hdf5
# 300/300 [==============================] - 33s 112ms/step - loss: 0.0483 - accuracy: 0.9860 - val_loss: 0.0517 - val_accuracy: 0.9835
# Epoch 8/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9882
# Epoch 00008: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.08-0.98.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 0.0399 - accuracy: 0.9882 - val_loss: 0.0468 - val_accuracy: 0.9848
# Epoch 9/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9898
# Epoch 00009: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.09-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0341 - accuracy: 0.9898 - val_loss: 0.0413 - val_accuracy: 0.9861
# Epoch 10/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9909
# Epoch 00010: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.10-0.99.hdf5
# 300/300 [==============================] - 34s 112ms/step - loss: 0.0305 - accuracy: 0.9909 - val_loss: 0.0383 - val_accuracy: 0.9876
# Epoch 11/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9923
# Epoch 00011: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.11-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 0.0261 - accuracy: 0.9923 - val_loss: 0.0427 - val_accuracy: 0.9875
# Epoch 12/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9933
# Epoch 00012: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.12-0.99.hdf5
# 300/300 [==============================] - 34s 114ms/step - loss: 0.0228 - accuracy: 0.9933 - val_loss: 0.0402 - val_accuracy: 0.9869
# Epoch 13/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9939
# Epoch 00013: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.13-0.99.hdf5
# 300/300 [==============================] - 34s 112ms/step - loss: 0.0202 - accuracy: 0.9939 - val_loss: 0.0369 - val_accuracy: 0.9878
# Epoch 14/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9950
# Epoch 00014: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.14-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0175 - accuracy: 0.9950 - val_loss: 0.0339 - val_accuracy: 0.9878
# Epoch 15/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9960
# Epoch 00015: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.15-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0149 - accuracy: 0.9960 - val_loss: 0.0348 - val_accuracy: 0.9881
# Epoch 16/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9962
# Epoch 00016: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.16-0.99.hdf5
# 300/300 [==============================] - 34s 112ms/step - loss: 0.0143 - accuracy: 0.9962 - val_loss: 0.0360 - val_accuracy: 0.9870
# Epoch 17/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9966
# Epoch 00017: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.17-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0124 - accuracy: 0.9966 - val_loss: 0.0325 - val_accuracy: 0.9881
# Epoch 18/50
# 229/300 [=====================>........] - ETA: 7s - loss: 0.0100 - accuracy: 0.9976

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.save(filepath='/content/drive/My Drive/Data Science/LeNet5_MNIST/MNIST_LeNet5.h5')

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model("/content/drive/My Drive/Data Science/LeNet5_MNIST/weights.17-0.99.hdf5")

# %%
#loss, acc = model.evaluate(X_test,y_test)
#print(loss)
#print(acc)

# %%
#filepath="/content/drive/My Drive/Data Science/checkpoint/weights.{epoch:02d}-{val_accuracy:.2f}.hdf5"

#checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, mode='max')

#callbacks_list = [checkpoint]

# %%
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history= model.fit(x=X_train, y=y_train, batch_size=200, epochs=50, validation_data=(X_test, y_test), callbacks=callbacks_list, initial_epoch=18)
history
# Out:
# Epoch 19/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9969
# Epoch 00019: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.19-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 0.0112 - accuracy: 0.9969 - val_loss: 0.0348 - val_accuracy: 0.9881
# Epoch 20/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9970
# Epoch 00020: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.20-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0335 - val_accuracy: 0.9877
# Epoch 21/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9977
# Epoch 00021: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.21-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 0.0092 - accuracy: 0.9977 - val_loss: 0.0349 - val_accuracy: 0.9883
# Epoch 22/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9974
# Epoch 00022: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.22-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.0318 - val_accuracy: 0.9892
# Epoch 23/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9980
# Epoch 00023: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.23-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.0335 - val_accuracy: 0.9890
# Epoch 24/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9982
# Epoch 00024: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.24-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.0321 - val_accuracy: 0.9897
# Epoch 25/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9981
# Epoch 00025: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.25-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.0352 - val_accuracy: 0.9885
# Epoch 26/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9992
# Epoch 00026: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.26-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0045 - accuracy: 0.9992 - val_loss: 0.0338 - val_accuracy: 0.9894
# Epoch 27/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9990
# Epoch 00027: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.27-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.0335 - val_accuracy: 0.9898
# Epoch 28/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9980
# Epoch 00028: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.28-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0419 - val_accuracy: 0.9876
# Epoch 29/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9960
# Epoch 00029: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.29-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0457 - val_accuracy: 0.9874
# Epoch 30/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9974
# Epoch 00030: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.30-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.0360 - val_accuracy: 0.9889
# Epoch 31/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9982
# Epoch 00031: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.31-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0342 - val_accuracy: 0.9885
# Epoch 32/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9993
# Epoch 00032: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.32-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0323 - val_accuracy: 0.9902
# Epoch 33/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9998
# Epoch 00033: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.33-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.0295 - val_accuracy: 0.9903
# Epoch 34/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 00034: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.34-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0297 - val_accuracy: 0.9908
# Epoch 35/50
# 300/300 [==============================] - ETA: 0s - loss: 7.5051e-04 - accuracy: 0.9999
# Epoch 00035: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.35-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 7.5051e-04 - accuracy: 0.9999 - val_loss: 0.0296 - val_accuracy: 0.9906
# Epoch 36/50
# 300/300 [==============================] - ETA: 0s - loss: 6.1422e-04 - accuracy: 0.9999
# Epoch 00036: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.36-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 6.1422e-04 - accuracy: 0.9999 - val_loss: 0.0302 - val_accuracy: 0.9904
# Epoch 37/50
# 300/300 [==============================] - ETA: 0s - loss: 5.3421e-04 - accuracy: 1.0000
# Epoch 00037: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.37-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 5.3421e-04 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9907
# Epoch 38/50
# 300/300 [==============================] - ETA: 0s - loss: 4.9398e-04 - accuracy: 1.0000
# Epoch 00038: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.38-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 4.9398e-04 - accuracy: 1.0000 - val_loss: 0.0304 - val_accuracy: 0.9909
# Epoch 39/50
# 300/300 [==============================] - ETA: 0s - loss: 4.2999e-04 - accuracy: 1.0000
# Epoch 00039: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.39-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 4.2999e-04 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9913
# Epoch 40/50
# 300/300 [==============================] - ETA: 0s - loss: 4.8182e-04 - accuracy: 1.0000
# Epoch 00040: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.40-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 4.8182e-04 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9908
# Epoch 41/50
# 300/300 [==============================] - ETA: 0s - loss: 5.6150e-04 - accuracy: 0.9999
# Epoch 00041: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.41-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 5.6150e-04 - accuracy: 0.9999 - val_loss: 0.0365 - val_accuracy: 0.9902
# Epoch 42/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9851
# Epoch 00042: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.42-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0457 - accuracy: 0.9851 - val_loss: 0.0480 - val_accuracy: 0.9867
# Epoch 43/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9925
# Epoch 00043: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.43-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.0351 - val_accuracy: 0.9883
# Epoch 44/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9959
# Epoch 00044: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.44-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 0.0333 - val_accuracy: 0.9889
# Epoch 45/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9974
# Epoch 00045: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.45-0.99.hdf5
# 300/300 [==============================] - 33s 111ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0348 - val_accuracy: 0.9899
# Epoch 46/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9984
# Epoch 00046: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.46-0.99.hdf5
# 300/300 [==============================] - 34s 112ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0307 - val_accuracy: 0.9901
# Epoch 47/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9994
# Epoch 00047: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.47-0.99.hdf5
# 300/300 [==============================] - 33s 110ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0327 - val_accuracy: 0.9908
# Epoch 48/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998
# Epoch 00048: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.48-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0307 - val_accuracy: 0.9910
# Epoch 49/50
# 300/300 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 00049: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.49-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0297 - val_accuracy: 0.9903
# Epoch 50/50
# 300/300 [==============================] - ETA: 0s - loss: 9.5340e-04 - accuracy: 0.9999
# Epoch 00050: saving model to /content/drive/My Drive/Data Science/LeNet5_MNIST/weights.50-0.99.hdf5
# 300/300 [==============================] - 33s 109ms/step - loss: 9.5340e-04 - accuracy: 0.9999 - val_loss: 0.0288 - val_accuracy: 0.9907
